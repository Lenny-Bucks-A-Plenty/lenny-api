# %%
import numpy as np
import pandas as pd
import yfinance as yf

# %%
import typing
class TickerData(typing.TypedDict):
    ticker: str
    name: str
    current_price: float
    percent_diff: float

def normalizeTicker(ticker: str):
    return ticker.replace('.', '-')

def denormalizeTicker(ticker: str):
    return ticker.replace('-', '.')

def getSP500Tickers():
    tickerTable = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]
    tickers = tickerTable.loc[:, ["Symbol"]].head(500)
    return list(map(normalizeTicker, tickers["Symbol"].tolist()))

# getSP500Tickers()

# %%
def getData(ticker: str):
    tickerObj = yf.Ticker(ticker)
    name = tickerObj.info['shortName']
    current_price = tickerObj.info['currentPrice']
    last_close_price = tickerObj.info['previousClose']
    percent_diff = round(((current_price - last_close_price) / abs(last_close_price)) * 100, ndigits=2)
    return TickerData(ticker=denormalizeTicker(ticker), name=name, current_price=current_price, percent_diff=percent_diff)

# getData('BRK-B')

res = []
tickers = getSP500Tickers()
for ticker in tickers:
    print(f'fetching data for {ticker} ...')
    data = getData(ticker)
    res.append(data)

print(res)
# Out:
# fetching data for MMM ...
# fetching data for AOS ...
# fetching data for ABT ...
# fetching data for ABBV ...
# fetching data for ACN ...
# fetching data for ADBE ...
# fetching data for AMD ...
# fetching data for AES ...
# fetching data for AFL ...
# fetching data for A ...
# fetching data for APD ...
# fetching data for ABNB ...
# fetching data for AKAM ...
# fetching data for ALB ...
# fetching data for ARE ...
# fetching data for ALGN ...
# fetching data for ALLE ...
# fetching data for LNT ...
# fetching data for ALL ...
# fetching data for GOOGL ...
# fetching data for GOOG ...
# fetching data for MO ...
# fetching data for AMZN ...
# fetching data for AMCR ...
# fetching data for AEE ...
# fetching data for AAL ...
# fetching data for AEP ...
# fetching data for AXP ...
# fetching data for AIG ...
# fetching data for AMT ...
# fetching data for AWK ...
# fetching data for AMP ...
# fetching data for AME ...
# fetching data for AMGN ...
# fetching data for APH ...
# fetching data for ADI ...
# fetching data for ANSS ...
# fetching data for AON ...
# fetching data for APA ...
# fetching data for AAPL ...
# fetching data for AMAT ...
# fetching data for APTV ...
# fetching data for ACGL ...
# fetching data for ADM ...
# fetching data for ANET ...
# fetching data for AJG ...
# fetching data for AIZ ...
# fetching data for T ...
# fetching data for ATO ...
# fetching data for ADSK ...
# fetching data for ADP ...
# fetching data for AZO ...
# fetching data for AVB ...
# fetching data for AVY ...
# fetching data for AXON ...
# fetching data for BKR ...
# fetching data for BALL ...
# fetching data for BAC ...
# fetching data for BK ...
# fetching data for BBWI ...
# fetching data for BAX ...
# fetching data for BDX ...
# fetching data for BRK-B ...
# fetching data for BBY ...
# fetching data for BIO ...
# fetching data for TECH ...
# fetching data for BIIB ...
# fetching data for BLK ...
# fetching data for BX ...
# fetching data for BA ...
# fetching data for BKNG ...
# fetching data for BWA ...
# fetching data for BXP ...
# fetching data for BSX ...
# fetching data for BMY ...
# fetching data for AVGO ...
# fetching data for BR ...
# fetching data for BRO ...
# fetching data for BF-B ...
# fetching data for BLDR ...
# fetching data for BG ...
# fetching data for CDNS ...
# fetching data for CZR ...
# fetching data for CPT ...
# fetching data for CPB ...
# fetching data for COF ...
# fetching data for CAH ...
# fetching data for KMX ...
# fetching data for CCL ...
# fetching data for CARR ...
# fetching data for CTLT ...
# fetching data for CAT ...
# fetching data for CBOE ...
# fetching data for CBRE ...
# fetching data for CDW ...
# fetching data for CE ...
# fetching data for COR ...
# fetching data for CNC ...
# fetching data for CNP ...
# fetching data for CF ...
# fetching data for CHRW ...
# fetching data for CRL ...
# fetching data for SCHW ...
# fetching data for CHTR ...
# fetching data for CVX ...
# fetching data for CMG ...
# fetching data for CB ...
# fetching data for CHD ...
# fetching data for CI ...
# fetching data for CINF ...
# fetching data for CTAS ...
# fetching data for CSCO ...
# fetching data for C ...
# fetching data for CFG ...
# fetching data for CLX ...
# fetching data for CME ...
# fetching data for CMS ...
# fetching data for KO ...
# fetching data for CTSH ...
# fetching data for CL ...
# fetching data for CMCSA ...
# fetching data for CMA ...
# fetching data for CAG ...
# fetching data for COP ...
# fetching data for ED ...
# fetching data for STZ ...
# fetching data for CEG ...
# fetching data for COO ...
# fetching data for CPRT ...
# fetching data for GLW ...
# fetching data for CPAY ...
# fetching data for CTVA ...
# fetching data for CSGP ...
# fetching data for COST ...
# fetching data for CTRA ...
# fetching data for CCI ...
# fetching data for CSX ...
# fetching data for CMI ...
# fetching data for CVS ...
# fetching data for DHR ...
# fetching data for DRI ...
# fetching data for DVA ...
# fetching data for DAY ...
# fetching data for DECK ...
# fetching data for DE ...
# fetching data for DAL ...
# fetching data for DVN ...
# fetching data for DXCM ...
# fetching data for FANG ...
# fetching data for DLR ...
# fetching data for DFS ...
# fetching data for DG ...
# fetching data for DLTR ...
# fetching data for D ...
# fetching data for DPZ ...
# fetching data for DOV ...
# fetching data for DOW ...
# fetching data for DHI ...
# fetching data for DTE ...
# fetching data for DUK ...
# fetching data for DD ...
# fetching data for EMN ...
# fetching data for ETN ...
# fetching data for EBAY ...
# fetching data for ECL ...
# fetching data for EIX ...
# fetching data for EW ...
# fetching data for EA ...
# fetching data for ELV ...
# fetching data for LLY ...
# fetching data for EMR ...
# fetching data for ENPH ...
# fetching data for ETR ...
# fetching data for EOG ...
# fetching data for EPAM ...
# fetching data for EQT ...
# fetching data for EFX ...
# fetching data for EQIX ...
# fetching data for EQR ...
# fetching data for ESS ...
# fetching data for EL ...
# fetching data for ETSY ...
# fetching data for EG ...
# fetching data for EVRG ...
# fetching data for ES ...
# fetching data for EXC ...
# fetching data for EXPE ...
# fetching data for EXPD ...
# fetching data for EXR ...
# fetching data for XOM ...
# fetching data for FFIV ...
# fetching data for FDS ...
# fetching data for FICO ...
# fetching data for FAST ...
# fetching data for FRT ...
# fetching data for FDX ...
# fetching data for FIS ...
# fetching data for FITB ...
# fetching data for FSLR ...
# fetching data for FE ...
# fetching data for FI ...
# fetching data for FMC ...
# fetching data for F ...
# fetching data for FTNT ...
# fetching data for FTV ...
# fetching data for FOXA ...
# fetching data for FOX ...
# fetching data for BEN ...
# fetching data for FCX ...
# fetching data for GRMN ...
# fetching data for IT ...
# fetching data for GE ...
# fetching data for GEHC ...
# fetching data for GEV ...
# fetching data for GEN ...
# fetching data for GNRC ...
# fetching data for GD ...
# fetching data for GIS ...
# fetching data for GM ...
# fetching data for GPC ...
# fetching data for GILD ...
# fetching data for GPN ...
# fetching data for GL ...
# fetching data for GS ...
# fetching data for HAL ...
# fetching data for HIG ...
# fetching data for HAS ...
# fetching data for HCA ...
# fetching data for DOC ...
# fetching data for HSIC ...
# fetching data for HSY ...
# fetching data for HES ...
# fetching data for HPE ...
# fetching data for HLT ...
# fetching data for HOLX ...
# fetching data for HD ...
# fetching data for HON ...
# fetching data for HRL ...
# fetching data for HST ...
# fetching data for HWM ...
# fetching data for HPQ ...
# fetching data for HUBB ...
# fetching data for HUM ...
# fetching data for HBAN ...
# fetching data for HII ...
# fetching data for IBM ...
# fetching data for IEX ...
# fetching data for IDXX ...
# fetching data for ITW ...
# fetching data for ILMN ...
# fetching data for INCY ...
# fetching data for IR ...
# fetching data for PODD ...
# fetching data for INTC ...
# fetching data for ICE ...
# fetching data for IFF ...
# fetching data for IP ...
# fetching data for IPG ...
# fetching data for INTU ...
# fetching data for ISRG ...
# fetching data for IVZ ...
# fetching data for INVH ...
# fetching data for IQV ...
# fetching data for IRM ...
# fetching data for JBHT ...
# fetching data for JBL ...
# fetching data for JKHY ...
# fetching data for J ...
# fetching data for JNJ ...
# fetching data for JCI ...
# fetching data for JPM ...
# fetching data for JNPR ...
# fetching data for K ...
# fetching data for KVUE ...
# fetching data for KDP ...
# fetching data for KEY ...
# fetching data for KEYS ...
# fetching data for KMB ...
# fetching data for KIM ...
# fetching data for KMI ...
# fetching data for KLAC ...
# fetching data for KHC ...
# fetching data for KR ...
# fetching data for LHX ...
# fetching data for LH ...
# fetching data for LRCX ...
# fetching data for LW ...
# fetching data for LVS ...
# fetching data for LDOS ...
# fetching data for LEN ...
# fetching data for LIN ...
# fetching data for LYV ...
# fetching data for LKQ ...
# fetching data for LMT ...
# fetching data for L ...
# fetching data for LOW ...
# fetching data for LULU ...
# fetching data for LYB ...
# fetching data for MTB ...
# fetching data for MRO ...
# fetching data for MPC ...
# fetching data for MKTX ...
# fetching data for MAR ...
# fetching data for MMC ...
# fetching data for MLM ...
# fetching data for MAS ...
# fetching data for MA ...
# fetching data for MTCH ...
# fetching data for MKC ...
# fetching data for MCD ...
# fetching data for MCK ...
# fetching data for MDT ...
# fetching data for MRK ...
# fetching data for META ...
# fetching data for MET ...
# fetching data for MTD ...
# fetching data for MGM ...
# fetching data for MCHP ...
# fetching data for MU ...
# fetching data for MSFT ...
# fetching data for MAA ...
# fetching data for MRNA ...
# fetching data for MHK ...
# fetching data for MOH ...
# fetching data for TAP ...
# fetching data for MDLZ ...
# fetching data for MPWR ...
# fetching data for MNST ...
# fetching data for MCO ...
# fetching data for MS ...
# fetching data for MOS ...
# fetching data for MSI ...
# fetching data for MSCI ...
# fetching data for NDAQ ...
# fetching data for NTAP ...
# fetching data for NFLX ...
# fetching data for NEM ...
# fetching data for NWSA ...
# fetching data for NWS ...
# fetching data for NEE ...
# fetching data for NKE ...
# fetching data for NI ...
# fetching data for NDSN ...
# fetching data for NSC ...
# fetching data for NTRS ...
# fetching data for NOC ...
# fetching data for NCLH ...
# fetching data for NRG ...
# fetching data for NUE ...
# fetching data for NVDA ...
# fetching data for NVR ...
# fetching data for NXPI ...
# fetching data for ORLY ...
# fetching data for OXY ...
# fetching data for ODFL ...
# fetching data for OMC ...
# fetching data for ON ...
# fetching data for OKE ...
# fetching data for ORCL ...
# fetching data for OTIS ...
# fetching data for PCAR ...
# fetching data for PKG ...
# fetching data for PANW ...
# fetching data for PARA ...
# fetching data for PH ...
# fetching data for PAYX ...
# fetching data for PAYC ...
# fetching data for PYPL ...
# fetching data for PNR ...
# fetching data for PEP ...
# fetching data for PFE ...
# fetching data for PCG ...
# fetching data for PM ...
# fetching data for PSX ...
# fetching data for PNW ...
# fetching data for PNC ...
# fetching data for POOL ...
# fetching data for PPG ...
# fetching data for PPL ...
# fetching data for PFG ...
# fetching data for PG ...
# fetching data for PGR ...
# fetching data for PLD ...
# fetching data for PRU ...
# fetching data for PEG ...
# fetching data for PTC ...
# fetching data for PSA ...
# fetching data for PHM ...
# fetching data for QRVO ...
# fetching data for PWR ...
# fetching data for QCOM ...
# fetching data for DGX ...
# fetching data for RL ...
# fetching data for RJF ...
# fetching data for RTX ...
# fetching data for O ...
# fetching data for REG ...
# fetching data for REGN ...
# fetching data for RF ...
# fetching data for RSG ...
# fetching data for RMD ...
# fetching data for RVTY ...
# fetching data for RHI ...
# fetching data for ROK ...
# fetching data for ROL ...
# fetching data for ROP ...
# fetching data for ROST ...
# fetching data for RCL ...
# fetching data for SPGI ...
# fetching data for CRM ...
# fetching data for SBAC ...
# fetching data for SLB ...
# fetching data for STX ...
# fetching data for SRE ...
# fetching data for NOW ...
# fetching data for SHW ...
# fetching data for SPG ...
# fetching data for SWKS ...
# fetching data for SJM ...
# fetching data for SNA ...
# fetching data for SOLV ...
# fetching data for SO ...
# fetching data for LUV ...
# fetching data for SWK ...
# fetching data for SBUX ...
# fetching data for STT ...
# fetching data for STLD ...
# fetching data for STE ...
# fetching data for SYK ...
# fetching data for SMCI ...
# fetching data for SYF ...
# fetching data for SNPS ...
# fetching data for SYY ...
# fetching data for TMUS ...
# fetching data for TROW ...
# fetching data for TTWO ...
# fetching data for TPR ...
# fetching data for TRGP ...
# fetching data for TGT ...
# fetching data for TEL ...
# fetching data for TDY ...
# fetching data for TFX ...
# fetching data for TER ...
# fetching data for TSLA ...
# fetching data for TXN ...
# fetching data for TXT ...
# fetching data for TMO ...
# fetching data for TJX ...
# fetching data for TSCO ...
# fetching data for TT ...
# fetching data for TDG ...
# fetching data for TRV ...
# fetching data for TRMB ...
# fetching data for TFC ...
# fetching data for TYL ...
# fetching data for TSN ...
# fetching data for USB ...
# fetching data for UBER ...
# fetching data for UDR ...
# fetching data for ULTA ...
# fetching data for UNP ...
# fetching data for UAL ...
# fetching data for UPS ...
# fetching data for URI ...
# fetching data for UNH ...
# fetching data for UHS ...
# fetching data for VLO ...
# fetching data for VTR ...
# fetching data for VLTO ...
# fetching data for VRSN ...
# fetching data for VRSK ...
# fetching data for VZ ...
# fetching data for VRTX ...
# fetching data for VTRS ...
# fetching data for VICI ...
# fetching data for V ...
# fetching data for VST ...
# fetching data for VMC ...
# fetching data for WRB ...
# fetching data for GWW ...
# fetching data for WAB ...
# fetching data for WBA ...
# fetching data for WMT ...
# fetching data for DIS ...
# fetching data for WBD ...
# fetching data for WM ...
# fetching data for WAT ...
# fetching data for WEC ...
# fetching data for WFC ...
# fetching data for WELL ...
# fetching data for WST ...
# fetching data for WDC ...
# fetching data for WRK ...
# fetching data for WY ...
# fetching data for WMB ...
# fetching data for WTW ...
# fetching data for WYNN ...
# fetching data for XEL ...
# fetching data for XYL ...
# fetching data for YUM ...
# [{'ticker': 'MMM', 'name': '3M Company', 'current_price': 101.49, 'percent_diff': -1.6}, {'ticker': 'AOS', 'name': 'A.O. Smith Corporation', 'current_price': 85.07, 'percent_diff': -0.78}, {'ticker': 'ABT', 'name': 'Abbott Laboratories', 'current_price': 104.82, 'percent_diff': 1.81}, {'ticker': 'ABBV', 'name': 'AbbVie Inc.', 'current_price': 159.61, 'percent_diff': -2.04}, {'ticker': 'ACN', 'name': 'Accenture plc', 'current_price': 307.11, 'percent_diff': 1.14}, {'ticker': 'ADBE', 'name': 'Adobe Inc.', 'current_price': 483.93, 'percent_diff': 0.43}, {'ticker': 'AMD', 'name': 'Advanced Micro Devices, Inc.', 'current_price': 165.52, 'percent_diff': 0.52}, {'ticker': 'AES', 'name': 'The AES Corporation', 'current_price': 20.93, 'percent_diff': -0.52}, {'ticker': 'AFL', 'name': 'AFLAC Incorporated', 'current_price': 87.66, 'percent_diff': 0.08}, {'ticker': 'A', 'name': 'Agilent Technologies, Inc.', 'current_price': 152.87, 'percent_diff': -0.52}, {'ticker': 'APD', 'name': 'Air Products and Chemicals, Inc', 'current_price': 264.65, 'percent_diff': -0.0}, {'ticker': 'ABNB', 'name': 'Airbnb, Inc.', 'current_price': 142.71, 'percent_diff': -0.96}, {'ticker': 'AKAM', 'name': 'Akamai Technologies, Inc.', 'current_price': 95.29, 'percent_diff': 0.84}, {'ticker': 'ALB', 'name': 'Albemarle Corporation', 'current_price': 126.48, 'percent_diff': -0.13}, {'ticker': 'ARE', 'name': 'Alexandria Real Estate Equities', 'current_price': 122.78, 'percent_diff': -0.57}, {'ticker': 'ALGN', 'name': 'Align Technology, Inc.', 'current_price': 261.12, 'percent_diff': -1.1}, {'ticker': 'ALLE', 'name': 'Allegion plc', 'current_price': 123.07, 'percent_diff': -0.39}, {'ticker': 'LNT', 'name': 'Alliant Energy Corporation', 'current_price': 51.17, 'percent_diff': -1.82}, {'ticker': 'ALL', 'name': 'Allstate Corporation (The)', 'current_price': 166.17, 'percent_diff': -1.2}, {'ticker': 'GOOGL', 'name': 'Alphabet Inc.', 'current_price': 176.38, 'percent_diff': -0.83}, {'ticker': 'GOOG', 'name': 'Alphabet Inc.', 'current_price': 178.0, 'percent_diff': -0.86}, {'ticker': 'MO', 'name': 'Altria Group, Inc.', 'current_price': 46.32, 'percent_diff': -0.02}, {'ticker': 'AMZN', 'name': 'Amazon.com, Inc.', 'current_price': 183.13, 'percent_diff': -0.01}, {'ticker': 'AMCR', 'name': 'Amcor plc', 'current_price': 10.07, 'percent_diff': 0.0}, {'ticker': 'AEE', 'name': 'Ameren Corporation', 'current_price': 73.2, 'percent_diff': -1.82}, {'ticker': 'AAL', 'name': 'American Airlines Group, Inc.', 'current_price': 14.1, 'percent_diff': 0.5}, {'ticker': 'AEP', 'name': 'American Electric Power Company', 'current_price': 91.48, 'percent_diff': -1.23}, {'ticker': 'AXP', 'name': 'American Express Company', 'current_price': 240.09, 'percent_diff': -1.23}, {'ticker': 'AIG', 'name': 'American International Group, I', 'current_price': 78.91, 'percent_diff': 0.29}, {'ticker': 'AMT', 'name': 'American Tower Corporation (REI', 'current_price': 191.34, 'percent_diff': -1.44}, {'ticker': 'AWK', 'name': 'American Water Works Company, I', 'current_price': 133.75, 'percent_diff': -0.45}, {'ticker': 'AMP', 'name': 'Ameriprise Financial, Inc.', 'current_price': 437.99, 'percent_diff': 0.9}, {'ticker': 'AME', 'name': 'AMETEK, Inc.', 'current_price': 174.13, 'percent_diff': 2.96}, {'ticker': 'AMGN', 'name': 'Amgen Inc.', 'current_price': 309.41, 'percent_diff': -1.73}, {'ticker': 'APH', 'name': 'Amphenol Corporation', 'current_price': 134.57, 'percent_diff': -0.61}, {'ticker': 'ADI', 'name': 'Analog Devices, Inc.', 'current_price': 240.16, 'percent_diff': 10.86}, {'ticker': 'ANSS', 'name': 'ANSYS, Inc.', 'current_price': 326.36, 'percent_diff': -0.13}, {'ticker': 'AON', 'name': 'Aon plc', 'current_price': 284.65, 'percent_diff': -1.84}, {'ticker': 'APA', 'name': 'APA Corporation', 'current_price': 30.13, 'percent_diff': -1.92}, {'ticker': 'AAPL', 'name': 'Apple Inc.', 'current_price': 190.9, 'percent_diff': -0.75}, {'ticker': 'AMAT', 'name': 'Applied Materials, Inc.', 'current_price': 218.15, 'perce ...

# %%
def getData2(tickersObj: dict, ticker: str):
    name = tickersObj.tickers[ticker].info['shortName']
    current_price = tickersObj.tickers[ticker].info['currentPrice']
    last_close_price = tickersObj.tickers[ticker].info['previousClose']
    percent_diff = round(((current_price - last_close_price) / abs(last_close_price)) * 100, ndigits=2)
    return TickerData(ticker=denormalizeTicker(ticker), name=name, current_price=current_price, percent_diff=percent_diff)

tickers = getSP500Tickers()
tickersObj = yf.Tickers(' '.join(tickers))
for ticker in tickers:
    print(getData2(tickersObj, ticker))
# Out:
# {'ticker': 'MMM', 'name': '3M Company', 'current_price': 101.53, 'percent_diff': -1.56}
# {'ticker': 'AOS', 'name': 'A.O. Smith Corporation', 'current_price': 85.56, 'percent_diff': -0.21}
# {'ticker': 'ABT', 'name': 'Abbott Laboratories', 'current_price': 104.4287, 'percent_diff': 1.43}
# {'ticker': 'ABBV', 'name': 'AbbVie Inc.', 'current_price': 160.04, 'percent_diff': -1.77}
# {'ticker': 'ACN', 'name': 'Accenture plc', 'current_price': 307.4625, 'percent_diff': 1.26}
# {'ticker': 'ADBE', 'name': 'Adobe Inc.', 'current_price': 483.87, 'percent_diff': 0.42}
# {'ticker': 'AMD', 'name': 'Advanced Micro Devices, Inc.', 'current_price': 168.2094, 'percent_diff': 2.16}
# {'ticker': 'AES', 'name': 'The AES Corporation', 'current_price': 21.075, 'percent_diff': 0.17}
# {'ticker': 'AFL', 'name': 'AFLAC Incorporated', 'current_price': 87.31, 'percent_diff': -0.32}
# {'ticker': 'A', 'name': 'Agilent Technologies, Inc.', 'current_price': 153.71, 'percent_diff': 0.03}
# {'ticker': 'APD', 'name': 'Air Products and Chemicals, Inc', 'current_price': 262.59, 'percent_diff': -0.78}
# {'ticker': 'ABNB', 'name': 'Airbnb, Inc.', 'current_price': 143.5575, 'percent_diff': -0.38}
# {'ticker': 'AKAM', 'name': 'Akamai Technologies, Inc.', 'current_price': 95.425, 'percent_diff': 0.98}
# {'ticker': 'ALB', 'name': 'Albemarle Corporation', 'current_price': 126.7387, 'percent_diff': 0.08}
# {'ticker': 'ARE', 'name': 'Alexandria Real Estate Equities', 'current_price': 123.51, 'percent_diff': 0.02}
# {'ticker': 'ALGN', 'name': 'Align Technology, Inc.', 'current_price': 264.005, 'percent_diff': -0.01}
# {'ticker': 'ALLE', 'name': 'Allegion plc', 'current_price': 123.07, 'percent_diff': -0.39}
# {'ticker': 'LNT', 'name': 'Alliant Energy Corporation', 'current_price': 51.825, 'percent_diff': -0.57}
# {'ticker': 'ALL', 'name': 'Allstate Corporation (The)', 'current_price': 167.05, 'percent_diff': -0.68}
# {'ticker': 'GOOGL', 'name': 'Alphabet Inc.', 'current_price': 175.95, 'percent_diff': -1.07}
# {'ticker': 'GOOG', 'name': 'Alphabet Inc.', 'current_price': 177.4801, 'percent_diff': -1.15}
# {'ticker': 'MO', 'name': 'Altria Group, Inc.', 'current_price': 46.42, 'percent_diff': 0.19}
# {'ticker': 'AMZN', 'name': 'Amazon.com, Inc.', 'current_price': 184.68, 'percent_diff': 0.84}
# {'ticker': 'AMCR', 'name': 'Amcor plc', 'current_price': 10.0612, 'percent_diff': -0.09}
# {'ticker': 'AEE', 'name': 'Ameren Corporation', 'current_price': 73.89, 'percent_diff': -0.9}
# {'ticker': 'AAL', 'name': 'American Airlines Group, Inc.', 'current_price': 14.195, 'percent_diff': 1.18}
# {'ticker': 'AEP', 'name': 'American Electric Power Company', 'current_price': 92.1, 'percent_diff': -0.56}
# {'ticker': 'AXP', 'name': 'American Express Company', 'current_price': 241.84, 'percent_diff': -0.51}
# {'ticker': 'AIG', 'name': 'American International Group, I', 'current_price': 79.21, 'percent_diff': 0.67}
# {'ticker': 'AMT', 'name': 'American Tower Corporation (REI', 'current_price': 192.17, 'percent_diff': -1.01}
# {'ticker': 'AWK', 'name': 'American Water Works Company, I', 'current_price': 134.31, 'percent_diff': -0.04}
# {'ticker': 'AMP', 'name': 'Ameriprise Financial, Inc.', 'current_price': 436.54, 'percent_diff': 0.57}
# {'ticker': 'AME', 'name': 'AMETEK, Inc.', 'current_price': 172.935, 'percent_diff': 2.25}
# {'ticker': 'AMGN', 'name': 'Amgen Inc.', 'current_price': 313.47, 'percent_diff': -0.44}
# {'ticker': 'APH', 'name': 'Amphenol Corporation', 'current_price': 135.75, 'percent_diff': 0.26}
# {'ticker': 'ADI', 'name': 'Analog Devices, Inc.', 'current_price': 234.63, 'percent_diff': 8.3}
# {'ticker': 'ANSS', 'name': 'ANSYS, Inc.', 'current_price': 328.04, 'percent_diff': 0.38}
# {'ticker': 'AON', 'name': 'Aon plc', 'current_price': 286.38, 'percent_diff': -1.24}
# {'ticker': 'APA', 'name': 'APA Corporation', 'current_price': 30.285, 'percent_diff': -1.42}
# {'ticker': 'AAPL', 'name': 'Apple Inc.', 'current_price': 192.09, 'percent_diff': -0.14}
# {'ticker': 'AMAT', 'name': 'Applied Materials, Inc.', 'current_price': 218.59, 'percent_diff': -0.37}
# {'ticker': 'APTV', 'name': 'Aptiv PLC', 'current_price': 82.38, 'percent_diff': 0.09}
# {'ticker': 'ACGL', 'name': 'Arch Capital Group Ltd.', 'current_price': 102.53, 'percent_diff': 0.87}
# {'ticker': 'ADM', 'name': 'Archer-Daniels-Midland Company', 'current_price': 61.465, 'percent_diff': 0.32}
# {'ticker': 'ANET', 'name': 'Arista Networks, Inc.', 'current_price': 320.66, 'percent_diff': 1.16}
# {'ticker': 'AJG', 'name': 'Arthur J. Gallagher & Co.', 'current_price': 257.23, 'percent_diff': -0.24}
# {'ticker': 'AIZ', 'name': 'Assurant, Inc.', 'current_price': 169.785, 'percent_diff': -0.93}
# {'ticker': 'T', 'name': 'AT&T Inc.', 'current_price': 17.425, 'percent_diff': 0.9}
# {'ticker': 'ATO', 'name': 'Atmos Energy Corporation', 'current_price': 118.09, 'percent_diff': -0.35}
# {'ticker': 'ADSK', 'name': 'Autodesk, Inc.', 'current_price': 221.68, 'percent_diff': 0.64}
# {'ticker': 'ADP', 'name': 'Automatic Data Processing, Inc.', 'current_price': 253.435, 'percent_diff': 0.51}
# {'ticker': 'AZO', 'name': 'AutoZone, Inc.', 'current_price': 2762.5, 'percent_diff': -2.07}
# {'ticker': 'AVB', 'name': 'AvalonBay Communities, Inc.', 'current_price': 199.18, 'percent_diff': 0.36}
# {'ticker': 'AVY', 'name': 'Avery Dennison Corporation', 'current_price': 229.28, 'percent_diff': 0.06}
# {'ticker': 'AXON', 'name': 'Axon Enterprise, Inc.', 'current_price': 286.7, 'percent_diff': -0.43}
# {'ticker': 'BKR', 'name': 'Baker Hughes Company', 'current_price': 32.2, 'percent_diff': -2.48}
# {'ticker': 'BALL', 'name': 'Ball Corporation', 'current_price': 69.8, 'percent_diff': -0.73}
# {'ticker': 'BAC', 'name': 'Bank of America Corporation', 'current_price': 39.52, 'percent_diff': -0.33}
# {'ticker': 'BK', 'name': 'The Bank of New York Mellon Cor', 'current_price': 58.725, 'percent_diff': -0.6}
# {'ticker': 'BBWI', 'name': 'Bath & Body Works, Inc.', 'current_price': 49.05, 'percent_diff': -1.92}
# {'ticker': 'BAX', 'name': 'Baxter International Inc.', 'current_price': 34.605, 'percent_diff': 0.45}
# {'ticker': 'BDX', 'name': 'Becton, Dickinson and Company', 'current_price': 235.21, 'percent_diff': 0.15}
# {'ticker': 'BRK.B', 'name': 'Berkshire Hathaway Inc. New', 'current_price': 413.8568, 'percent_diff': -0.12}
# {'ticker': 'BBY', 'name': 'Best Buy Co., Inc.', 'current_price': 71.8, 'percent_diff': -1.2}
# {'ticker': 'BIO', 'name': 'Bio-Rad Laboratories, Inc.', 'current_price': 292.905, 'percent_diff': 1.19}
# {'ticker': 'TECH', 'name': 'Bio-Techne Corp', 'current_price': 82.14, 'percent_diff': -0.65}
# {'ticker': 'BIIB', 'name': 'Biogen Inc.', 'current_price': 224.29, 'percent_diff': -1.49}
# {'ticker': 'BLK', 'name': 'BlackRock, Inc.', 'current_price': 803.27, 'percent_diff': -0.21}
# {'ticker': 'BX', 'name': 'Blackstone Inc.', 'current_price': 127.31, 'percent_diff': -0.31}
# {'ticker': 'BA', 'name': 'Boeing Company (The)', 'current_price': 185.12, 'percent_diff': 0.18}
# {'ticker': 'BKNG', 'name': 'Booking Holdings Inc. Common St', 'current_price': 3837.03, 'percent_diff': 0.38}
# {'ticker': 'BWA', 'name': 'BorgWarner Inc.', 'current_price': 36.0235, 'percent_diff': -1.31}
# {'ticker': 'BXP', 'name': 'Boston Properties, Inc.', 'current_price': 62.15, 'percent_diff': -0.32}
# {'ticker': 'BSX', 'name': 'Boston Scientific Corporation', 'current_price': 75.23, 'percent_diff': -0.58}
# {'ticker': 'BMY', 'name': 'Bristol-Myers Squibb Company', 'current_price': 42.57, 'percent_diff': 0.71}
# {'ticker': 'AVGO', 'name': 'Broadcom Inc.', 'current_price': 1400.025, 'percent_diff': 0.06}
# {'ticker': 'BR', 'name': 'Broadridge Financial Solutions,', 'current_price': 204.01, 'percent_diff': 2.02}
# {'ticker': 'BRO', 'name': 'Brown & Brown, Inc.', 'current_price': 91.1025, 'percent_diff': 1.39}
# {'ticker': 'BF.B', 'name': 'Brown Forman Inc', 'current_price': 47.29, 'percent_diff': -0.04}
# {'ticker': 'BLDR', 'name': 'Builders FirstSource, Inc.', 'current_price': 167.7, 'percent_diff': -0.14}
# {'ticker': 'BG', 'name': 'Bunge Limited', 'current_price': 102.781, 'percent_diff': -0.51}
# {'ticker': 'CDNS', 'name': 'Cadence Design Systems, Inc.', 'current_price': 293.485, 'percent_diff': 1.17}
# {'ticker': 'CZR', 'name': 'Caesars Entertainment, Inc.', 'current_price': 35.07, 'percent_diff': -1.46}
# {'ticker': 'CPT', 'name': 'Camden Property Trust', 'current_price': 106.2, 'percent_diff': 0.26}
# {'ticker': 'CPB', 'name': 'Campbell Soup Company', 'current_price': 45.79, 'percent_diff': -0.52}
# {'ticker': 'COF', 'name': 'Capital One Financial Corporati', 'current_price': 140.69, 'percent_diff': 0.19}
# {'ticker': 'CAH', 'name': 'Cardinal Health, Inc.', 'current_price': 96.72, 'percent_diff': 0.74}
# {'ticker': 'KMX', 'name': 'CarMax Inc', 'current_price': 71.31, 'percent_diff': -0.92}
# {'ticker': 'CCL', 'name': 'Carnival Corporation', 'current_price': 15.8902, 'percent_diff': -1.91}
# {'ticker': 'CARR', 'name': 'Carrier Global Corporation', 'current_price': 65.5, 'percent_diff': -1.09}
# {'ticker': 'CTLT', 'name': 'Catalent, Inc.', 'current_price': 54.82, 'percent_diff': -0.25}
# {'ticker': 'CAT', 'name': 'Caterpillar, Inc.', 'current_price': 355.39, 'percent_diff': -1.02}
# {'ticker': 'CBOE', 'name': 'Cboe Global Markets, Inc.', 'current_price': 184.145, 'percent_diff': 0.22}
# {'ticker': 'CBRE', 'name': 'CBRE Group Inc', 'current_price': 89.93, 'percent_diff': -0.54}
# {'ticker': 'CDW', 'name': 'CDW Corporation', 'current_price': 234.59, 'percent_diff': 1.83}
# {'ticker': 'CE', 'name': 'Celanese Corporation', 'current_price': 153.99, 'percent_diff': -0.93}
# {'ticker': 'COR', 'name': 'Cencora, Inc.', 'current_price': 217.0619, 'percent_diff': -0.01}
# {'ticker': 'CNC', 'name': 'Centene Corporation', 'current_price': 78.4, 'percent_diff': 0.0}
# {'ticker': 'CNP', 'name': 'CenterPoint Energy, Inc (Holdin', 'current_price': 30.35, 'percent_diff': -0.2}
# {'ticker': 'CF', 'name': 'CF Industries Holdings, Inc.', 'current_price': 79.3338, 'percent_diff': 0.96}
# {'ticker': 'CHRW', 'name': 'C.H. Robinson Worldwide, Inc.', 'current_price': 83.56, 'percent_diff': 1.16}
# {'ticker': 'CRL', 'name': 'Charles River Laboratories Inte', 'current_price': 220.134, 'percent_diff': -0.61}
# {'ticker': 'SCHW', 'name': 'Charles Schwab Corporation (The', 'current_price': 78.01, 'percent_diff': -1.13}
# {'ticker': 'CHTR', 'name': 'Charter Communications, Inc.', 'current_price': 270.6, 'percent_diff': -1.64}
# {'ticker': 'CVX', 'name': 'Chevron Corporation', 'current_price': 157.7977, 'percent_diff': -1.36}
# {'ticker': 'CMG', 'name': 'Chipotle Mexican Grill, Inc.', 'current_price': 3157.48, 'percent_diff': -0.48}
# {'ticker': 'CB', 'name': 'Chubb Limited', 'current_price': 267.97, 'percent_diff': 1.12}
# {'ticker': 'CHD', 'name': 'Church & Dwight Company, Inc.', 'current_price': 107.06, 'percent_diff': 0.0}
# {'ticker': 'CI', 'name': 'The Cigna Group', 'current_price': 334.46, 'percent_diff': -0.57}
# {'ticker': 'CINF', 'name': 'Cincinnati Financial Corporatio', 'current_price': 118.74, 'percent_diff': 0.13}
# {'ticker': 'CTAS', 'name': 'Cintas Corporation', 'current_price': 701.865, 'percent_diff': 0.27}
# {'ticker': 'CSCO', 'name': 'Cisco Systems, Inc.', 'current_price': 47.325, 'percent_diff': 0.82}
# {'ticker': 'C', 'name': 'Citigroup, Inc.', 'current_price': 64.21, 'percent_diff': -0.82}
# {'ticker': 'CFG', 'name': 'Citizens Financial Group, Inc.', 'current_price': 36.2, 'percent_diff': -1.01}
# {'ticker': 'CLX', 'name': 'Clorox Company (The)', 'current_price': 134.245, 'percent_diff': -0.09}
# {'ticker': 'CME', 'name': 'CME Group Inc.', 'current_price': 210.37, 'percent_diff': 0.01}
# {'ticker': 'CMS', 'name': 'CMS Energy Corporation', 'current_price': 62.44, 'percent_diff': -0.27}
# {'ticker': 'KO', 'name': 'Coca-Cola Company (The)', 'current_price': 62.81, 'percent_diff': -0.16}
# {'ticker': 'CTSH', 'name': 'Cognizant Technology Solutions ', 'current_price': 68.97, 'percent_diff': 0.26}
# {'ticker': 'CL', 'name': 'Colgate-Palmolive Company', 'current_price': 94.73, 'percent_diff': -0.46}
# {'ticker': 'CMCSA', 'name': 'Comcast Corporation', 'current_price': 38.8957, 'percent_diff': -0.8}
# {'ticker': 'CMA', 'name': 'Comerica Incorporated', 'current_price': 53.23, 'percent_diff': -0.69}
# {'ticker': 'CAG', 'name': 'ConAgra Brands, Inc.', 'current_price': 30.4308, 'percent_diff': -1.17}
# {'ticker': 'COP', 'name': 'ConocoPhillips', 'current_price': 118.2, 'percent_diff': -1.84}
# {'ticker': 'ED', 'name': 'Consolidated Edison, Inc.', 'current_price': 97.905, 'percent_diff': 1.62}
# {'ticker': 'STZ', 'name': 'Constellation Brands, Inc.', 'current_price': 249.375, 'percent_diff': -0.64}
# {'ticker': 'CEG', 'name': 'Constellation Energy Corporatio', 'current_price': 218.56, 'percent_diff': -1.81}
# {'ticker': 'COO', 'name': 'The Cooper Companies, Inc.', 'current_price': 96.68, 'percent_diff': -0.08}
# {'ticker': 'CPRT', 'name': 'Copart, Inc.', 'current_price': 54.58, 'percent_diff': -0.64}
# {'ticker': 'GLW', 'name': 'Corning Incorporated', 'current_price': 36.4958, 'percent_diff': 0.04}
# {'ticker': 'CPAY', 'name': 'Corpay, Inc.', 'current_price': 274.24, 'percent_diff': 0.41}
# {'ticker': 'CTVA', 'name': 'Corteva, Inc.', 'current_price': 56.71, 'percent_diff': 0.11}
# {'ticker': 'CSGP', 'name': 'CoStar Group, Inc.', 'current_price': 87.26, 'percent_diff': 0.47}
# {'ticker': 'COST', 'name': 'Costco Wholesale Corporation', 'current_price': 803.345, 'percent_diff': 0.3}
# {'ticker': 'CTRA', 'name': 'Coterra Energy Inc.', 'current_price': 27.418, 'percent_diff': -1.52}
# {'ticker': 'CCI', 'name': 'Crown Castle Inc.', 'current_price': 100.085, 'percent_diff': -0.66}
# {'ticker': 'CSX', 'name': 'CSX Corporation', 'current_price': 33.655, 'percent_diff': 1.77}
# {'ticker': 'CMI', 'name': 'Cummins Inc.', 'current_price': 287.34, 'percent_diff': 0.48}
# {'ticker': 'CVS', 'name': 'CVS Health Corporation', 'current_price': 57.43, 'percent_diff': 0.19}
# {'ticker': 'DHR', 'name': 'Danaher Corporation', 'current_price': 268.265, 'percent_diff': 0.64}
# {'ticker': 'DRI', 'name': 'Darden Restaurants, Inc.', 'current_price': 148.9, 'percent_diff': -0.53}
# {'ticker': 'DVA', 'name': 'DaVita Inc.', 'current_price': 134.86, 'percent_diff': -2.76}
# {'ticker': 'DAY', 'name': 'Dayforce, Inc.', 'current_price': 63.02, 'percent_diff': 3.23}
# {'ticker': 'DECK', 'name': 'Deckers Outdoor Corporation', 'current_price': 895.26, 'percent_diff': -0.5}
# {'ticker': 'DE', 'name': 'Deere & Company', 'current_price': 386.995, 'percent_diff': 0.07}
# {'ticker': 'DAL', 'name': 'Delta Air Lines, Inc.', 'current_price': 51.8525, 'percent_diff': -0.72}
# {'ticker': 'DVN', 'name': 'Devon Energy Corporation', 'current_price': 48.75, 'percent_diff': -2.05}
# {'ticker': 'DXCM', 'name': 'DexCom, Inc.', 'current_price': 131.01, 'percent_diff': 0.13}
# {'ticker': 'FANG', 'name': 'Diamondback Energy, Inc.', 'current_price': 192.57, 'percent_diff': -2.03}
# {'ticker': 'DLR', 'name': 'Digital Realty Trust, Inc.', 'current_price': 142.73, 'percent_diff': -1.06}
# {'ticker': 'DFS', 'name': 'Discover Financial Services', 'current_price': 125.22, 'percent_diff': 0.59}
# {'ticker': 'DG', 'name': 'Dollar General Corporation', 'current_price': 141.695, 'percent_diff': -0.63}
# {'ticker': 'DLTR', 'name': 'Dollar Tree, Inc.', 'current_price': 115.02, 'percent_diff': 0.28}
# {'ticker': 'D', 'name': 'Dominion Energy, Inc.', 'current_price': 53.75, 'percent_diff': -0.35}
# {'ticker': 'DPZ', 'name': "Domino's Pizza Inc", 'current_price': 509.48, 'percent_diff': -0.83}
# {'ticker': 'DOV', 'name': 'Dover Corporation', 'current_price': 187.34, 'percent_diff': 0.69}
# {'ticker': 'DOW', 'name': 'Dow Inc.', 'current_price': 57.64, 'percent_diff': -2.16}
# {'ticker': 'DHI', 'name': 'D.R. Horton, Inc.', 'current_price': 146.055, 'percent_diff': -2.23}
# {'ticker': 'DTE', 'name': 'DTE Energy Company', 'current_price': 116.5625, 'percent_diff': -0.53}
# {'ticker': 'DUK', 'name': 'Duke Energy Corporation (Holdin', 'current_price': 104.25, 'percent_diff': -0.12}
# {'ticker': 'DD', 'name': 'DuPont de Nemours, Inc.', 'current_price': 78.585, 'percent_diff': -1.18}
# {'ticker': 'EMN', 'name': 'Eastman Chemical Company', 'current_price': 99.5452, 'percent_diff': -0.41}
# {'ticker': 'ETN', 'name': 'Eaton Corporation, PLC', 'current_price': 334.75, 'percent_diff': -0.59}
# {'ticker': 'EBAY', 'name': 'eBay Inc.', 'current_price': 52.3, 'percent_diff': 0.25}
# {'ticker': 'ECL', 'name': 'Ecolab Inc.', 'current_price': 234.63, 'percent_diff': -0.16}
# {'ticker': 'EIX', 'name': 'Edison International', 'current_price': 76.165, 'percent_diff': -0.79}
# {'ticker': 'EW', 'name': 'Edwards Lifesciences Corporatio', 'current_price': 90.625, 'percent_diff': 0.32}
# {'ticker': 'EA', 'name': 'Electronic Arts Inc.', 'current_price': 133.65, 'percent_diff': 3.73}
# {'ticker': 'ELV', 'name': 'Elevance Health, Inc.', 'current_price': 548.165, 'percent_diff': 0.47}
# {'ticker': 'LLY', 'name': 'Eli Lilly and Company', 'current_price': 797.475, 'percent_diff': -0.71}
# {'ticker': 'EMR', 'name': 'Emerson Electric Company', 'current_price': 113.6, 'percent_diff': -0.09}
# {'ticker': 'ENPH', 'name': 'Enphase Energy, Inc.', 'current_price': 121.5, 'percent_diff': 8.97}
# {'ticker': 'ETR', 'name': 'Entergy Corporation', 'current_price': 113.5707, 'percent_diff': -0.57}
# {'ticker': 'EOG', 'name': 'EOG Resources, Inc.', 'current_price': 126.17, 'percent_diff': -2.12}
# {'ticker': 'EPAM', 'name': 'EPAM Systems, Inc.', 'current_price': 189.954, 'percent_diff': -0.68}
# {'ticker': 'EQT', 'name': 'EQT Corporation', 'current_price': 40.87, 'percent_diff': -0.78}
# {'ticker': 'EFX', 'name': 'Equifax, Inc.', 'current_price': 241.97, 'percent_diff': 1.65}
# {'ticker': 'EQIX', 'name': 'Equinix, Inc.', 'current_price': 786.37, 'percent_diff': -0.74}
# {'ticker': 'EQR', 'name': 'Equity Residential', 'current_price': 67.2, 'percent_diff': 0.6}
# {'ticker': 'ESS', 'name': 'Essex Property Trust, Inc.', 'current_price': 265.09, 'percent_diff': 0.35}
# {'ticker': 'EL', 'name': 'Estee Lauder Companies, Inc. (T', 'current_price': 131.21, 'percent_diff': -1.14}
# {'ticker': 'ETSY', 'name': 'Etsy, Inc.', 'current_price': 64.03, 'percent_diff': -0.23}
# {'ticker': 'EG', 'name': 'Everest Group, Ltd.', 'current_price': 397.745, 'percent_diff': 0.91}
# {'ticker': 'EVRG', 'name': 'Evergy, Inc.', 'current_price': 55.41, 'percent_diff': -0.4}
# {'ticker': 'ES', 'name': 'Eversource Energy (D/B/A)', 'current_price': 60.895, 'percent_diff': -0.53}
# {'ticker': 'EXC', 'name': 'Exelon Corporation', 'current_price': 38.295, 'percent_diff': -0.58}
# {'ticker': 'EXPE', 'name': 'Expedia Group, Inc.', 'current_price': 111.74, 'percent_diff': 0.03}
# {'ticker': 'EXPD', 'name': 'Expeditors International of Was', 'current_price': 117.52, 'percent_diff': -0.17}
# {'ticker': 'EXR', 'name': 'Extra Space Storage Inc', 'current_price': 147.46, 'percent_diff': 0.94}
# {'ticker': 'XOM', 'name': 'Exxon Mobil Corporation', 'current_price': 115.785, 'percent_diff': -1.75}
# {'ticker': 'FFIV', 'name': 'F5, Inc.', 'current_price': 173.57, 'percent_diff': 0.07}
# {'ticker': 'FDS', 'name': 'FactSet Research Systems Inc.', 'current_price': 449.84, 'percent_diff': -0.02}
# {'ticker': 'FICO', 'name': 'Fair Isaac Corproation', 'current_price': 1388.405, 'percent_diff': 0.99}
# {'ticker': 'FAST', 'name': 'Fastenal Company', 'current_price': 66.58, 'percent_diff': 0.41}
# {'ticker': 'FRT', 'name': 'Federal Realty Investment Trust', 'current_price': 101.44, 'percent_diff': 0.15}
# {'ticker': 'FDX', 'name': 'FedEx Corporation', 'current_price': 250.59, 'percent_diff': -0.69}
# {'ticker': 'FIS', 'name': 'Fidelity National Information S', 'current_price': 77.52, 'percent_diff': -0.76}
# {'ticker': 'FITB', 'name': 'Fifth Third Bancorp', 'current_price': 37.665, 'percent_diff': -0.99}
# {'ticker': 'FSLR', 'name': 'First Solar, Inc.', 'current_price': 242.6, 'percent_diff': 14.37}
# {'ticker': 'FE', 'name': 'FirstEnergy Corp.', 'current_price': 40.345, 'percent_diff': -0.21}
# {'ticker': 'FI', 'name': 'Fiserv, Inc.', 'current_price': 152.08, 'percent_diff': -0.45}
# {'ticker': 'FMC', 'name': 'FMC Corporation', 'current_price': 63.495, 'percent_diff': -0.84}
# {'ticker': 'F', 'name': 'Ford Motor Company', 'current_price': 12.045, 'percent_diff': -0.86}
# {'ticker': 'FTNT', 'name': 'Fortinet, Inc.', 'current_price': 61.65, 'percent_diff': 0.55}
# {'ticker': 'FTV', 'name': 'Fortive Corporation', 'current_price': 77.04, 'percent_diff': -0.08}
# {'ticker': 'FOXA', 'name': 'Fox Corporation', 'current_price': 32.765, 'percent_diff': -0.32}
# {'ticker': 'FOX', 'name': 'Fox Corporation', 'current_price': 30.31, 'percent_diff': -0.3}
# {'ticker': 'BEN', 'name': 'Franklin Resources, Inc.', 'current_price': 23.98, 'percent_diff': 0.46}
# {'ticker': 'FCX', 'name': 'Freeport-McMoRan, Inc.', 'current_price': 50.8082, 'percent_diff': -6.47}
# {'ticker': 'GRMN', 'name': 'Garmin Ltd.', 'current_price': 162.71, 'percent_diff': -4.7}
# {'ticker': 'IT', 'name': 'Gartner, Inc.', 'current_price': 454.89, 'percent_diff': 1.23}
# {'ticker': 'GE', 'name': 'GE Aerospace', 'current_price': 160.81, 'percent_diff': -0.12}
# {'ticker': 'GEHC', 'name': 'GE HealthCare Technologies Inc.', 'current_price': 81.21, 'percent_diff': -0.89}
# {'ticker': 'GEV', 'name': 'GE Vernova Inc.', 'current_price': 165.45, 'percent_diff': 0.93}
# {'ticker': 'GEN', 'name': 'Gen Digital Inc.', 'current_price': 25.11, 'percent_diff': 0.24}
# {'ticker': 'GNRC', 'name': 'Generac Holdlings Inc.', 'current_price': 154.02, 'percent_diff': -0.14}
# {'ticker': 'GD', 'name': 'General Dynamics Corporation', 'current_price': 297.94, 'percent_diff': 0.3}
# {'ticker': 'GIS', 'name': 'General Mills, Inc.', 'current_price': 69.95, 'percent_diff': -0.96}
# {'ticker': 'GM', 'name': 'General Motors Company', 'current_price': 44.12, 'percent_diff': -1.78}
# {'ticker': 'GPC', 'name': 'Genuine Parts Company', 'current_price': 150.35, 'percent_diff': -0.77}
# {'ticker': 'GILD', 'name': 'Gilead Sciences, Inc.', 'current_price': 67.5, 'percent_diff': 0.31}
# {'ticker': 'GPN', 'name': 'Global Payments Inc.', 'current_price': 105.945, 'percent_diff': -1.32}
# {'ticker': 'GL', 'name': 'Globe Life Inc.', 'current_price': 85.21, 'percent_diff': 2.26}
# {'ticker': 'GS', 'name': 'Goldman Sachs Group, Inc. (The)', 'current_price': 465.61, 'percent_diff': -1.02}
# {'ticker': 'HAL', 'name': 'Halliburton Company', 'current_price': 36.635, 'percent_diff': -2.64}
# {'ticker': 'HIG', 'name': 'Hartford Financial Services Gro', 'current_price': 102.122, 'percent_diff': 0.0}
# {'ticker': 'HAS', 'name': 'Hasbro, Inc.', 'current_price': 60.825, 'percent_diff': -2.65}
# {'ticker': 'HCA', 'name': 'HCA Healthcare, Inc.', 'current_price': 320.65, 'percent_diff': -0.15}
# {'ticker': 'DOC', 'name': 'Healthpeak Properties, Inc.', 'current_price': 19.645, 'percent_diff': -0.53}
# {'ticker': 'HSIC', 'name': 'Henry Schein, Inc.', 'current_price': 73.1, 'percent_diff': -0.2}
# {'ticker': 'HSY', 'name': 'The Hershey Company', 'current_price': 206.085, 'percent_diff': -0.61}
# {'ticker': 'HES', 'name': 'Hess Corporation', 'current_price': 152.31, 'percent_diff': -1.49}
# {'ticker': 'HPE', 'name': 'Hewlett Packard Enterprise Comp', 'current_price': 17.81, 'percent_diff': 0.17}
# {'ticker': 'HLT', 'name': 'Hilton Worldwide Holdings Inc.', 'current_price': 206.24, 'percent_diff': 0.21}
# {'ticker': 'HOLX', 'name': 'Hologic, Inc.', 'current_price': 74.99, 'percent_diff': 0.59}
# {'ticker': 'HD', 'name': 'Home Depot, Inc. (The)', 'current_price': 333.03, 'percent_diff': -0.93}
# {'ticker': 'HON', 'name': 'Honeywell International Inc.', 'current_price': 203.57, 'percent_diff': 0.03}
# {'ticker': 'HRL', 'name': 'Hormel Foods Corporation', 'current_price': 35.475, 'percent_diff': -2.62}
# {'ticker': 'HST', 'name': 'Host Hotels & Resorts, Inc.', 'current_price': 18.475, 'percent_diff': 0.74}
# {'ticker': 'HWM', 'name': 'Howmet Aerospace Inc.', 'current_price': 84.11, 'percent_diff': -0.8}
# {'ticker': 'HPQ', 'name': 'HP Inc.', 'current_price': 33.135, 'percent_diff': 1.36}
# {'ticker': 'HUBB', 'name': 'Hubbell Inc', 'current_price': 404.29, 'percent_diff': 0.07}
# {'ticker': 'HUM', 'name': 'Humana Inc.', 'current_price': 355.44, 'percent_diff': -0.05}
# {'ticker': 'HBAN', 'name': 'Huntington Bancshares Incorpora', 'current_price': 14.005, 'percent_diff': -1.02}
# {'ticker': 'HII', 'name': 'Huntington Ingalls Industries, ', 'current_price': 252.805, 'percent_diff': -0.38}
# {'ticker': 'IBM', 'name': 'International Business Machines', 'current_price': 173.81, 'percent_diff': 0.2}
# {'ticker': 'IEX', 'name': 'IDEX Corporation', 'current_price': 217.88, 'percent_diff': 0.35}
# {'ticker': 'IDXX', 'name': 'IDEXX Laboratories, Inc.', 'current_price': 518.8, 'percent_diff': 0.07}
# {'ticker': 'ITW', 'name': 'Illinois Tool Works Inc.', 'current_price': 248.83, 'percent_diff': 0.02}
# {'ticker': 'ILMN', 'name': 'Illumina, Inc.', 'current_price': 108.38, 'percent_diff': 0.72}
# {'ticker': 'INCY', 'name': 'Incyte Corporation', 'current_price': 57.83, 'percent_diff': 0.75}
# {'ticker': 'IR', 'name': 'Ingersoll Rand Inc.', 'current_price': 95.525, 'percent_diff': 0.34}
# {'ticker': 'PODD', 'name': 'Insulet Corporation', 'current_price': 181.595, 'percent_diff': -0.65}
# {'ticker': 'INTC', 'name': 'Intel Corporation', 'current_price': 32.005, 'percent_diff': 0.83}
# {'ticker': 'ICE', 'name': 'Intercontinental Exchange Inc.', 'current_price': 136.715, 'percent_diff': -0.4}
# {'ticker': 'IFF', 'name': 'International Flavors & Fragran', 'current_price': 96.825, 'percent_diff': -1.1}
# {'ticker': 'IP', 'name': 'International Paper Company', 'current_price': 41.22, 'percent_diff': -1.6}
# {'ticker': 'IPG', 'name': 'Interpublic Group of Companies,', 'current_price': 31.6, 'percent_diff': 0.38}
# {'ticker': 'INTU', 'name': 'Intuit Inc.', 'current_price': 671.53, 'percent_diff': 0.56}
# {'ticker': 'ISRG', 'name': 'Intuitive Surgical, Inc.', 'current_price': 402.59, 'percent_diff': 0.12}
# {'ticker': 'IVZ', 'name': 'Invesco Ltd', 'current_price': 15.85, 'percent_diff': -0.69}
# {'ticker': 'INVH', 'name': 'Invitation Homes Inc.', 'current_price': 35.4, 'percent_diff': 0.63}
# {'ticker': 'IQV', 'name': 'IQVIA Holdings, Inc.', 'current_price': 226.79, 'percent_diff': -1.13}
# {'ticker': 'IRM', 'name': 'Iron Mountain Incorporated (Del', 'current_price': 81.15, 'percent_diff': -2.05}
# {'ticker': 'JBHT', 'name': 'J.B. Hunt Transport Services, I', 'current_price': 158.39, 'percent_diff': -0.61}
# {'ticker': 'JBL', 'name': 'Jabil Inc.', 'current_price': 118.135, 'percent_diff': 0.29}
# {'ticker': 'JKHY', 'name': 'Jack Henry & Associates, Inc.', 'current_price': 169.28, 'percent_diff': 0.12}
# {'ticker': 'J', 'name': 'Jacobs Solutions Inc.', 'current_price': 137.36, 'percent_diff': -1.03}
# {'ticker': 'JNJ', 'name': 'Johnson & Johnson', 'current_price': 153.17, 'percent_diff': 1.28}
# {'ticker': 'JCI', 'name': 'Johnson Controls International ', 'current_price': 72.66, 'percent_diff': -0.27}
# {'ticker': 'JPM', 'name': 'JP Morgan Chase & Co.', 'current_price': 198.6741, 'percent_diff': -0.42}
# {'ticker': 'JNPR', 'name': 'Juniper Networks, Inc.', 'current_price': 34.655, 'percent_diff': 0.3}
# {'ticker': 'K', 'name': 'Kellanova', 'current_price': 61.7, 'percent_diff': -0.88}
# {'ticker': 'KVUE', 'name': 'Kenvue Inc.', 'current_price': 19.935, 'percent_diff': -0.18}
# {'ticker': 'KDP', 'name': 'Keurig Dr Pepper Inc.', 'current_price': 34.18, 'percent_diff': 0.65}
# {'ticker': 'KEY', 'name': 'KeyCorp', 'current_price': 15.085, 'percent_diff': -1.53}
# {'ticker': 'KEYS', 'name': 'Keysight Technologies Inc.', 'current_price': 148.08, 'percent_diff': 1.18}
# {'ticker': 'KMB', 'name': 'Kimberly-Clark Corporation', 'current_price': 133.566, 'percent_diff': -0.13}
# {'ticker': 'KIM', 'name': 'Kimco Realty Corporation (HC)', 'current_price': 19.03, 'percent_diff': 0.05}
# {'ticker': 'KMI', 'name': 'Kinder Morgan, Inc.', 'current_price': 19.405, 'percent_diff': -1.7}
# {'ticker': 'KLAC', 'name': 'KLA Corporation', 'current_price': 772.465, 'percent_diff': 0.96}
# {'ticker': 'KHC', 'name': 'The Kraft Heinz Company', 'current_price': 36.19, 'percent_diff': 0.75}
# {'ticker': 'KR', 'name': 'Kroger Company (The)', 'current_price': 53.65, 'percent_diff': -0.02}
# {'ticker': 'LHX', 'name': 'L3Harris Technologies, Inc.', 'current_price': 224.9, 'percent_diff': -0.16}
# {'ticker': 'LH', 'name': 'Laboratory Corporation of Ameri', 'current_price': 203.6, 'percent_diff': -0.85}
# {'ticker': 'LRCX', 'name': 'Lam Research Corporation', 'current_price': 958.6665, 'percent_diff': -0.55}
# {'ticker': 'LW', 'name': 'Lamb Weston Holdings, Inc.', 'current_price': 88.59, 'percent_diff': 1.56}
# {'ticker': 'LVS', 'name': 'Las Vegas Sands Corp.', 'current_price': 45.81, 'percent_diff': -0.87}
# {'ticker': 'LDOS', 'name': 'Leidos Holdings, Inc.', 'current_price': 150.55, 'percent_diff': 0.18}
# {'ticker': 'LEN', 'name': 'Lennar Corporation', 'current_price': 157.84, 'percent_diff': -2.99}
# {'ticker': 'LIN', 'name': 'Linde plc', 'current_price': 434.8, 'percent_diff': -0.06}
# {'ticker': 'LYV', 'name': 'Live Nation Entertainment, Inc.', 'current_price': 101.445, 'percent_diff': -0.52}
# {'ticker': 'LKQ', 'name': 'LKQ Corporation', 'current_price': 44.44, 'percent_diff': -0.13}
# {'ticker': 'LMT', 'name': 'Lockheed Martin Corporation', 'current_price': 468.13, 'percent_diff': -0.04}
# {'ticker': 'L', 'name': 'Loews Corporation', 'current_price': 75.99, 'percent_diff': -0.29}
# {'ticker': 'LOW', 'name': "Lowe's Companies, Inc.", 'current_price': 223.47, 'percent_diff': -0.62}
# {'ticker': 'LULU', 'name': 'lululemon athletica inc.', 'current_price': 304.35, 'percent_diff': -5.77}
# {'ticker': 'LYB', 'name': 'LyondellBasell Industries NV', 'current_price': 98.24, 'percent_diff': -1.9}
# {'ticker': 'MTB', 'name': 'M&T Bank Corporation', 'current_price': 152.755, 'percent_diff': -0.41}
# {'ticker': 'MRO', 'name': 'Marathon Oil Corporation', 'current_price': 25.735, 'percent_diff': -2.11}
# {'ticker': 'MPC', 'name': 'Marathon Petroleum Corporation', 'current_price': 174.615, 'percent_diff': -1.11}
# {'ticker': 'MKTX', 'name': 'MarketAxess Holdings, Inc.', 'current_price': 219.835, 'percent_diff': 1.05}
# {'ticker': 'MAR', 'name': 'Marriott International', 'current_price': 237.685, 'percent_diff': -0.25}
# {'ticker': 'MMC', 'name': 'Marsh & McLennan Companies, Inc', 'current_price': 210.31, 'percent_diff': 0.18}
# {'ticker': 'MLM', 'name': 'Martin Marietta Materials, Inc.', 'current_price': 575.06, 'percent_diff': -1.08}
# {'ticker': 'MAS', 'name': 'Masco Corporation', 'current_price': 69.5, 'percent_diff': -0.57}
# {'ticker': 'MA', 'name': 'Mastercard Incorporated', 'current_price': 459.335, 'percent_diff': 0.05}
# {'ticker': 'MTCH', 'name': 'Match Group, Inc.', 'current_price': 29.9325, 'percent_diff': -0.32}
# {'ticker': 'MKC', 'name': 'McCormick & Company, Incorporat', 'current_price': 73.77, 'percent_diff': -0.31}
# {'ticker': 'MCD', 'name': "McDonald's Corporation", 'current_price': 265.77, 'percent_diff': -0.04}
# {'ticker': 'MCK', 'name': 'McKesson Corporation', 'current_price': 554.555, 'percent_diff': 0.39}
# {'ticker': 'MDT', 'name': 'Medtronic plc.', 'current_price': 85.64, 'percent_diff': 0.55}
# {'ticker': 'MRK', 'name': 'Merck & Company, Inc.', 'current_price': 130.91, 'percent_diff': 0.11}
# {'ticker': 'META', 'name': 'Meta Platforms, Inc.', 'current_price': 472.4521, 'percent_diff': 1.68}
# {'ticker': 'MET', 'name': 'MetLife, Inc.', 'current_price': 72.98, 'percent_diff': 0.54}
# {'ticker': 'MTD', 'name': 'Mettler-Toledo International, I', 'current_price': 1513.0, 'percent_diff': -0.54}
# {'ticker': 'MGM', 'name': 'MGM Resorts International', 'current_price': 40.24, 'percent_diff': -1.4}
# {'ticker': 'MCHP', 'name': 'Microchip Technology Incorporat', 'current_price': 98.6207, 'percent_diff': 2.97}
# {'ticker': 'MU', 'name': 'Micron Technology, Inc.', 'current_price': 127.06, 'percent_diff': -0.35}
# {'ticker': 'MSFT', 'name': 'Microsoft Corporation', 'current_price': 430.88, 'percent_diff': 0.43}
# {'ticker': 'MAA', 'name': 'Mid-America Apartment Communiti', 'current_price': 137.175, 'percent_diff': 0.49}
# {'ticker': 'MRNA', 'name': 'Moderna, Inc.', 'current_price': 158.1901, 'percent_diff': 10.09}
# {'ticker': 'MHK', 'name': 'Mohawk Industries, Inc.', 'current_price': 118.455, 'percent_diff': -0.92}
# {'ticker': 'MOH', 'name': 'Molina Healthcare Inc', 'current_price': 344.31, 'percent_diff': 0.58}
# {'ticker': 'TAP', 'name': 'Molson Coors Beverage Company', 'current_price': 54.8398, 'percent_diff': -0.58}
# {'ticker': 'MDLZ', 'name': 'Mondelez International, Inc.', 'current_price': 69.865, 'percent_diff': -1.13}
# {'ticker': 'MPWR', 'name': 'Monolithic Power Systems, Inc.', 'current_price': 768.69, 'percent_diff': 1.58}
# {'ticker': 'MNST', 'name': 'Monster Beverage Corporation', 'current_price': 53.23, 'percent_diff': -0.28}
# {'ticker': 'MCO', 'name': "Moody's Corporation", 'current_price': 416.17, 'percent_diff': 0.78}
# {'ticker': 'MS', 'name': 'Morgan Stanley', 'current_price': 100.96, 'percent_diff': -0.56}
# {'ticker': 'MOS', 'name': 'Mosaic Company (The)', 'current_price': 31.65, 'percent_diff': 2.56}
# {'ticker': 'MSI', 'name': 'Motorola Solutions, Inc.', 'current_price': 370.08, 'percent_diff': 0.09}
# {'ticker': 'MSCI', 'name': 'MSCI Inc.', 'current_price': 500.09, 'percent_diff': -1.08}
# {'ticker': 'NDAQ', 'name': 'Nasdaq, Inc.', 'current_price': 62.45, 'percent_diff': 0.02}
# {'ticker': 'NTAP', 'name': 'NetApp, Inc.', 'current_price': 113.42, 'percent_diff': 0.42}
# {'ticker': 'NFLX', 'name': 'Netflix, Inc.', 'current_price': 644.755, 'percent_diff': -0.9}
# {'ticker': 'NEM', 'name': 'Newmont Corporation', 'current_price': 42.8198, 'percent_diff': -2.77}
# {'ticker': 'NWSA', 'name': 'News Corporation', 'current_price': 26.21, 'percent_diff': -0.3}
# {'ticker': 'NWS', 'name': 'News Corporation', 'current_price': 27.04, 'percent_diff': -0.18}
# {'ticker': 'NEE', 'name': 'NextEra Energy, Inc.', 'current_price': 76.94, 'percent_diff': -0.01}
# {'ticker': 'NKE', 'name': 'Nike, Inc.', 'current_price': 92.485, 'percent_diff': -0.36}
# {'ticker': 'NI', 'name': 'NiSource Inc', 'current_price': 29.035, 'percent_diff': -0.6}
# {'ticker': 'NDSN', 'name': 'Nordson Corporation', 'current_price': 244.55, 'percent_diff': 0.58}
# {'ticker': 'NSC', 'name': 'Norfolk Southern Corporation', 'current_price': 232.22, 'percent_diff': 3.34}
# {'ticker': 'NTRS', 'name': 'Northern Trust Corporation', 'current_price': 84.06, 'percent_diff': -0.64}
# {'ticker': 'NOC', 'name': 'Northrop Grumman Corporation', 'current_price': 472.08, 'percent_diff': 0.04}
# {'ticker': 'NCLH', 'name': 'Norwegian Cruise Line Holdings ', 'current_price': 16.475, 'percent_diff': -2.69}
# {'ticker': 'NRG', 'name': 'NRG Energy, Inc.', 'current_price': 80.58, 'percent_diff': -2.95}
# {'ticker': 'NUE', 'name': 'Nucor Corporation', 'current_price': 171.4808, 'percent_diff': -0.37}
# {'ticker': 'NVDA', 'name': 'NVIDIA Corporation', 'current_price': 949.89, 'percent_diff': -0.42}
# {'ticker': 'NVR', 'name': 'NVR, Inc.', 'current_price': 7529.5, 'percent_diff': -1.19}
# {'ticker': 'NXPI', 'name': 'NXP Semiconductors N.V.', 'current_price': 278.825, 'percent_diff': 1.61}
# {'ticker': 'ORLY', 'name': "O'Reilly Automotive, Inc.", 'current_price': 993.89, 'percent_diff': -0.17}
# {'ticker': 'OXY', 'name': 'Occidental Petroleum Corporatio', 'current_price': 62.63, 'percent_diff': -1.14}
# {'ticker': 'ODFL', 'name': 'Old Dominion Freight Line, Inc.', 'current_price': 174.09, 'percent_diff': -0.78}
# {'ticker': 'OMC', 'name': 'Omnicom Group Inc.', 'current_price': 94.8, 'percent_diff': -0.18}
# {'ticker': 'ON', 'name': 'ON Semiconductor Corporation', 'current_price': 75.57, 'percent_diff': 3.78}
# {'ticker': 'OKE', 'name': 'ONEOK, Inc.', 'current_price': 81.98, 'percent_diff': -1.24}
# {'ticker': 'ORCL', 'name': 'Oracle Corporation', 'current_price': 124.1355, 'percent_diff': -0.4}
# {'ticker': 'OTIS', 'name': 'Otis Worldwide Corporation', 'current_price': 97.998, 'percent_diff': -0.15}
# {'ticker': 'PCAR', 'name': 'PACCAR Inc.', 'current_price': 106.94, 'percent_diff': 1.27}
# {'ticker': 'PKG', 'name': 'Packaging Corporation of Americ', 'current_price': 181.87, 'percent_diff': 0.01}
# {'ticker': 'PANW', 'name': 'Palo Alto Networks, Inc.', 'current_price': 310.0714, 'percent_diff': -0.51}
# {'ticker': 'PARA', 'name': 'Paramount Global', 'current_price': 12.095, 'percent_diff': -0.04}
# {'ticker': 'PH', 'name': 'Parker-Hannifin Corporation', 'current_price': 547.475, 'percent_diff': 0.11}
# {'ticker': 'PAYX', 'name': 'Paychex, Inc.', 'current_price': 126.79, 'percent_diff': 0.71}
# {'ticker': 'PAYC', 'name': 'Paycom Software, Inc.', 'current_price': 180.28, 'percent_diff': 0.34}
# {'ticker': 'PYPL', 'name': 'PayPal Holdings, Inc.', 'current_price': 62.7, 'percent_diff': -2.18}
# {'ticker': 'PNR', 'name': 'Pentair plc.', 'current_price': 84.24, 'percent_diff': -0.04}
# {'ticker': 'PEP', 'name': 'Pepsico, Inc.', 'current_price': 181.19, 'percent_diff': 0.06}
# {'ticker': 'PFE', 'name': 'Pfizer, Inc.', 'current_price': 29.2255, 'percent_diff': 2.33}
# {'ticker': 'PCG', 'name': 'Pacific Gas & Electric Co.', 'current_price': 18.89, 'percent_diff': -0.16}
# {'ticker': 'PM', 'name': 'Philip Morris International Inc', 'current_price': 100.99, 'percent_diff': 0.76}
# {'ticker': 'PSX', 'name': 'Phillips 66', 'current_price': 142.39, 'percent_diff': -1.21}
# {'ticker': 'PNW', 'name': 'Pinnacle West Capital Corporati', 'current_price': 78.25, 'percent_diff': -0.47}
# {'ticker': 'PNC', 'name': 'PNC Financial Services Group, I', 'current_price': 157.0111, 'percent_diff': -0.97}
# {'ticker': 'POOL', 'name': 'Pool Corporation', 'current_price': 374.11, 'percent_diff': 0.8}
# {'ticker': 'PPG', 'name': 'PPG Industries, Inc.', 'current_price': 134.155, 'percent_diff': 0.32}
# {'ticker': 'PPL', 'name': 'PPL Corporation', 'current_price': 29.79, 'percent_diff': -0.17}
# {'ticker': 'PFG', 'name': 'Principal Financial Group Inc', 'current_price': 83.22, 'percent_diff': -0.32}
# {'ticker': 'PG', 'name': 'Procter & Gamble Company (The)', 'current_price': 167.87, 'percent_diff': -0.29}
# {'ticker': 'PGR', 'name': 'Progressive Corporation (The)', 'current_price': 207.95, 'percent_diff': -0.68}
# {'ticker': 'PLD', 'name': 'Prologis, Inc.', 'current_price': 111.085, 'percent_diff': 0.44}
# {'ticker': 'PRU', 'name': 'Prudential Financial, Inc.', 'current_price': 119.41, 'percent_diff': 1.33}
# {'ticker': 'PEG', 'name': 'Public Service Enterprise Group', 'current_price': 74.71, 'percent_diff': -0.59}
# {'ticker': 'PTC', 'name': 'PTC Inc.', 'current_price': 183.61, 'percent_diff': 0.51}
# {'ticker': 'PSA', 'name': 'Public Storage', 'current_price': 283.93, 'percent_diff': 0.32}
# {'ticker': 'PHM', 'name': 'PulteGroup, Inc.', 'current_price': 114.7578, 'percent_diff': -2.67}
# {'ticker': 'QRVO', 'name': 'Qorvo, Inc.', 'current_price': 99.2, 'percent_diff': 1.23}
# {'ticker': 'PWR', 'name': 'Quanta Services, Inc.', 'current_price': 270.525, 'percent_diff': -0.56}
# {'ticker': 'QCOM', 'name': 'QUALCOMM Incorporated', 'current_price': 204.67, 'percent_diff': 1.9}
# {'ticker': 'DGX', 'name': 'Quest Diagnostics Incorporated', 'current_price': 142.49, 'percent_diff': -0.59}
# {'ticker': 'RL', 'name': 'Ralph Lauren Corporation', 'current_price': 165.9, 'percent_diff': -1.25}
# {'ticker': 'RJF', 'name': 'Raymond James Financial, Inc.', 'current_price': 123.39, 'percent_diff': -1.12}
# {'ticker': 'RTX', 'name': 'RTX Corporation', 'current_price': 105.85, 'percent_diff': 0.4}
# {'ticker': 'O', 'name': 'Realty Income Corporation', 'current_price': 54.71, 'percent_diff': -0.67}
# {'ticker': 'REG', 'name': 'Regency Centers Corporation', 'current_price': 60.38, 'percent_diff': 0.35}
# {'ticker': 'REGN', 'name': 'Regeneron Pharmaceuticals, Inc.', 'current_price': 990.595, 'percent_diff': -0.34}
# {'ticker': 'RF', 'name': 'Regions Financial Corporation', 'current_price': 19.6, 'percent_diff': -1.46}
# {'ticker': 'RSG', 'name': 'Republic Services, Inc.', 'current_price': 186.615, 'percent_diff': 0.07}
# {'ticker': 'RMD', 'name': 'ResMed Inc.', 'current_price': 218.735, 'percent_diff': 0.21}
# {'ticker': 'RVTY', 'name': 'Revvity, Inc.', 'current_price': 113.3, 'percent_diff': 0.06}
# {'ticker': 'RHI', 'name': 'Robert Half Inc.', 'current_price': 68.34, 'percent_diff': -0.6}
# {'ticker': 'ROK', 'name': 'Rockwell Automation, Inc.', 'current_price': 273.23, 'percent_diff': 1.06}
# {'ticker': 'ROL', 'name': 'Rollins, Inc.', 'current_price': 46.31, 'percent_diff': -0.41}
# {'ticker': 'ROP', 'name': 'Roper Technologies, Inc.', 'current_price': 547.41, 'percent_diff': 1.11}
# {'ticker': 'ROST', 'name': 'Ross Stores, Inc.', 'current_price': 131.835, 'percent_diff': -0.35}
# {'ticker': 'RCL', 'name': 'Royal Caribbean Cruises Ltd.', 'current_price': 148.715, 'percent_diff': -1.35}
# {'ticker': 'SPGI', 'name': 'S&P Global Inc.', 'current_price': 440.47, 'percent_diff': 0.14}
# {'ticker': 'CRM', 'name': 'Salesforce, Inc.', 'current_price': 286.755, 'percent_diff': 1.06}
# {'ticker': 'SBAC', 'name': 'SBA Communications Corporation', 'current_price': 194.86, 'percent_diff': -1.28}
# {'ticker': 'SLB', 'name': 'Schlumberger N.V.', 'current_price': 46.96, 'percent_diff': -2.75}
# {'ticker': 'STX', 'name': 'Seagate Technology Holdings PLC', 'current_price': 94.72, 'percent_diff': 1.2}
# {'ticker': 'SRE', 'name': 'DBA Sempra', 'current_price': 78.01, 'percent_diff': -0.5}
# {'ticker': 'NOW', 'name': 'ServiceNow, Inc.', 'current_price': 780.395, 'percent_diff': 0.43}
# {'ticker': 'SHW', 'name': 'Sherwin-Williams Company (The)', 'current_price': 308.735, 'percent_diff': -0.4}
# {'ticker': 'SPG', 'name': 'Simon Property Group, Inc.', 'current_price': 146.64, 'percent_diff': -0.9}
# {'ticker': 'SWKS', 'name': 'Skyworks Solutions, Inc.', 'current_price': 93.42, 'percent_diff': 1.05}
# {'ticker': 'SJM', 'name': 'The J.M. Smucker Company', 'current_price': 111.78, 'percent_diff': -0.25}
# {'ticker': 'SNA', 'name': 'Snap-On Incorporated', 'current_price': 276.618, 'percent_diff': 0.19}
# {'ticker': 'SOLV', 'name': 'Solventum Corporation', 'current_price': 61.7, 'percent_diff': 0.78}
# {'ticker': 'SO', 'name': 'Southern Company (The)', 'current_price': 79.54, 'percent_diff': -0.3}
# {'ticker': 'LUV', 'name': 'Southwest Airlines Company', 'current_price': 28.015, 'percent_diff': 0.16}
# {'ticker': 'SWK', 'name': 'Stanley Black & Decker, Inc.', 'current_price': 88.065, 'percent_diff': -0.12}
# {'ticker': 'SBUX', 'name': 'Starbucks Corporation', 'current_price': 80.19, 'percent_diff': 3.18}
# {'ticker': 'STT', 'name': 'State Street Corporation', 'current_price': 76.57, 'percent_diff': -0.66}
# {'ticker': 'STLD', 'name': 'Steel Dynamics, Inc.', 'current_price': 132.47, 'percent_diff': -1.4}
# {'ticker': 'STE', 'name': 'STERIS plc (Ireland)', 'current_price': 231.13, 'percent_diff': 0.23}
# {'ticker': 'SYK', 'name': 'Stryker Corporation', 'current_price': 334.425, 'percent_diff': 1.18}
# {'ticker': 'SMCI', 'name': 'Super Micro Computer, Inc.', 'current_price': 896.5, 'percent_diff': -0.27}
# {'ticker': 'SYF', 'name': 'Synchrony Financial', 'current_price': 43.98, 'percent_diff': -1.83}
# {'ticker': 'SNPS', 'name': 'Synopsys, Inc.', 'current_price': 576.075, 'percent_diff': 0.8}
# {'ticker': 'SYY', 'name': 'Sysco Corporation', 'current_price': 76.01, 'percent_diff': 0.92}
# {'ticker': 'TMUS', 'name': 'T-Mobile US, Inc.', 'current_price': 165.54, 'percent_diff': 0.72}
# {'ticker': 'TROW', 'name': 'T. Rowe Price Group, Inc.', 'current_price': 118.28, 'percent_diff': 0.55}
# {'ticker': 'TTWO', 'name': 'Take-Two Interactive Software, ', 'current_price': 150.955, 'percent_diff': -0.31}
# {'ticker': 'TPR', 'name': 'Tapestry, Inc.', 'current_price': 41.605, 'percent_diff': -1.76}
# {'ticker': 'TRGP', 'name': 'Targa Resources, Inc.', 'current_price': 114.95, 'percent_diff': -2.75}
# {'ticker': 'TGT', 'name': 'Target Corporation', 'current_price': 144.59, 'percent_diff': -7.18}
# {'ticker': 'TEL', 'name': 'TE Connectivity Ltd. New Switze', 'current_price': 152.175, 'percent_diff': 0.25}
# {'ticker': 'TDY', 'name': 'Teledyne Technologies Incorpora', 'current_price': 411.14, 'percent_diff': 0.79}
# {'ticker': 'TFX', 'name': 'Teleflex Incorporated', 'current_price': 213.38, 'percent_diff': 0.18}
# {'ticker': 'TER', 'name': 'Teradyne, Inc.', 'current_price': 140.87, 'percent_diff': 0.43}
# {'ticker': 'TSLA', 'name': 'Tesla, Inc.', 'current_price': 180.7619, 'percent_diff': -3.13}
# {'ticker': 'TXN', 'name': 'Texas Instruments Incorporated', 'current_price': 202.515, 'percent_diff': 1.76}
# {'ticker': 'TXT', 'name': 'Textron Inc.', 'current_price': 88.95, 'percent_diff': 0.15}
# {'ticker': 'TMO', 'name': 'Thermo Fisher Scientific Inc', 'current_price': 594.675, 'percent_diff': 0.77}
# {'ticker': 'TJX', 'name': 'TJX Companies, Inc. (The)', 'current_price': 102.82, 'percent_diff': 5.24}
# {'ticker': 'TSCO', 'name': 'Tractor Supply Company', 'current_price': 284.28, 'percent_diff': -0.49}
# {'ticker': 'TT', 'name': 'Trane Technologies plc', 'current_price': 333.39, 'percent_diff': -0.65}
# {'ticker': 'TDG', 'name': 'Transdigm Group Incorporated', 'current_price': 1336.31, 'percent_diff': -0.04}
# {'ticker': 'TRV', 'name': 'The Travelers Companies, Inc.', 'current_price': 216.525, 'percent_diff': 0.13}
# {'ticker': 'TRMB', 'name': 'Trimble Inc.', 'current_price': 58.44, 'percent_diff': 1.99}
# {'ticker': 'TFC', 'name': 'Truist Financial Corporation', 'current_price': 38.99, 'percent_diff': -1.39}
# {'ticker': 'TYL', 'name': 'Tyler Technologies, Inc.', 'current_price': 499.495, 'percent_diff': 0.71}
# {'ticker': 'TSN', 'name': 'Tyson Foods, Inc.', 'current_price': 60.94, 'percent_diff': -0.16}
# {'ticker': 'USB', 'name': 'U.S. Bancorp', 'current_price': 40.94, 'percent_diff': -0.58}
# {'ticker': 'UBER', 'name': 'Uber Technologies, Inc.', 'current_price': 65.255, 'percent_diff': 2.01}
# {'ticker': 'UDR', 'name': 'UDR, Inc.', 'current_price': 39.83, 'percent_diff': 0.35}
# {'ticker': 'ULTA', 'name': 'Ulta Beauty, Inc.', 'current_price': 381.53, 'percent_diff': -0.08}
# {'ticker': 'UNP', 'name': 'Union Pacific Corporation', 'current_price': 234.6635, 'percent_diff': -0.13}
# {'ticker': 'UAL', 'name': 'United Airlines Holdings, Inc.', 'current_price': 52.8, 'percent_diff': -0.43}
# {'ticker': 'UPS', 'name': 'United Parcel Service, Inc.', 'current_price': 144.02, 'percent_diff': -0.96}
# {'ticker': 'URI', 'name': 'United Rentals, Inc.', 'current_price': 685.125, 'percent_diff': -1.36}
# {'ticker': 'UNH', 'name': 'UnitedHealth Group Incorporated', 'current_price': 522.37, 'percent_diff': -0.23}
# {'ticker': 'UHS', 'name': 'Universal Health Services, Inc.', 'current_price': 180.43, 'percent_diff': 0.13}
# {'ticker': 'VLO', 'name': 'Valero Energy Corporation', 'current_price': 160.1, 'percent_diff': -1.41}
# {'ticker': 'VTR', 'name': 'Ventas, Inc.', 'current_price': 48.385, 'percent_diff': 0.03}
# {'ticker': 'VLTO', 'name': 'Veralto Corp', 'current_price': 100.6, 'percent_diff': 1.08}
# {'ticker': 'VRSN', 'name': 'VeriSign, Inc.', 'current_price': 174.92, 'percent_diff': 0.4}
# {'ticker': 'VRSK', 'name': 'Verisk Analytics, Inc.', 'current_price': 253.285, 'percent_diff': 0.71}
# {'ticker': 'VZ', 'name': 'Verizon Communications Inc.', 'current_price': 39.9801, 'percent_diff': 0.91}
# {'ticker': 'VRTX', 'name': 'Vertex Pharmaceuticals Incorpor', 'current_price': 446.62, 'percent_diff': 1.05}
# {'ticker': 'VTRS', 'name': 'Viatris Inc.', 'current_price': 10.98, 'percent_diff': 0.18}
# {'ticker': 'VICI', 'name': 'VICI Properties Inc.', 'current_price': 29.825, 'percent_diff': -0.98}
# {'ticker': 'V', 'name': 'Visa Inc.', 'current_price': 277.05, 'percent_diff': 0.4}
# {'ticker': 'VST', 'name': 'Vistra Corp.', 'current_price': 93.535, 'percent_diff': -0.75}
# {'ticker': 'VMC', 'name': 'Vulcan Materials Company (Holdi', 'current_price': 259.57, 'percent_diff': -1.0}
# {'ticker': 'WRB', 'name': 'W.R. Berkley Corporation', 'current_price': 80.065, 'percent_diff': 1.05}
# {'ticker': 'GWW', 'name': 'W.W. Grainger, Inc.', 'current_price': 967.02, 'percent_diff': 1.07}
# {'ticker': 'WAB', 'name': 'Westinghouse Air Brake Technolo', 'current_price': 169.36, 'percent_diff': -0.41}
# {'ticker': 'WBA', 'name': 'Walgreens Boots Alliance, Inc.', 'current_price': 16.6667, 'percent_diff': -0.08}
# {'ticker': 'WMT', 'name': 'Walmart Inc.', 'current_price': 65.355, 'percent_diff': 0.31}
# {'ticker': 'DIS', 'name': 'Walt Disney Company (The)', 'current_price': 103.64, 'percent_diff': 0.61}
# {'ticker': 'WBD', 'name': 'Warner Bros. Discovery, Inc. - ', 'current_price': 7.86, 'percent_diff': -0.38}
# {'ticker': 'WM', 'name': 'Waste Management, Inc.', 'current_price': 209.6, 'percent_diff': 0.61}
# {'ticker': 'WAT', 'name': 'Waters Corporation', 'current_price': 350.8, 'percent_diff': -0.24}
# {'ticker': 'WEC', 'name': 'WEC Energy Group, Inc.', 'current_price': 83.69, 'percent_diff': -1.05}
# {'ticker': 'WFC', 'name': 'Wells Fargo & Company', 'current_price': 60.835, 'percent_diff': -1.02}
# {'ticker': 'WELL', 'name': 'Welltower Inc.', 'current_price': 102.23, 'percent_diff': 1.12}
# {'ticker': 'WST', 'name': 'West Pharmaceutical Services, I', 'current_price': 338.04, 'percent_diff': 0.31}
# {'ticker': 'WDC', 'name': 'Western Digital Corporation', 'current_price': 73.9, 'percent_diff': -0.15}
# {'ticker': 'WRK', 'name': 'Westrock Company', 'current_price': 52.8873, 'percent_diff': 0.3}
# {'ticker': 'WY', 'name': 'Weyerhaeuser Company', 'current_price': 30.94, 'percent_diff': -0.55}
# {'ticker': 'WMB', 'name': 'Williams Companies, Inc. (The)', 'current_price': 40.865, 'percent_diff': -2.19}
# {'ticker': 'WTW', 'name': 'Willis Towers Watson Public Lim', 'current_price': 256.4025, 'percent_diff': 0.99}
# {'ticker': 'WYNN', 'name': 'Wynn Resorts, Limited', 'current_price': 95.42, 'percent_diff': -1.21}
# {'ticker': 'XEL', 'name': 'Xcel Energy Inc.', 'current_price': 56.255, 'percent_diff': -0.85}
# {'ticker': 'XYL', 'name': 'Xylem Inc.', 'current_price': 145.46, 'percent_diff': -0.34}
# {'ticker': 'YUM', 'name': 'Yum! Brands, Inc.', 'current_price': 138.34, 'percent_diff': -0.69}

# %%
# get the data using yfinance
#data = yf.download(ticker, interval='1d', period="max")
# get the current price of each stock
#price_now = data['Adj Close'][-1]
# find % difference between now and prior close price
#pct_diff = (price_now - data['Adj Close'][0])/data['Adj Close'][0]*100
# return [ticker, round(price_now, 2), round(pct_diff, 2)]

ticker = 'MSFT'
yticker = yf.Ticker('MSFT')
name = yticker.info['shortName']
data = yticker.history(interval='30m', period='1d')
print(data)
last_close_price = yticker.history(interval='1d', period='2d')['Close'][0]
current_price = yticker.history(interval='15m', period='1d')['Close'][-1]
percent_diff = ((current_price - last_close_price) / last_close_price) * 100
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2024-05-15 09:30:00-04:00  417.899994  420.450012  417.269989  418.269989
# 2024-05-15 10:00:00-04:00  418.209991  419.500000  418.200012  419.390015
# 2024-05-15 10:30:00-04:00  419.450012  420.299988  418.980011  420.139893
# 2024-05-15 11:00:00-04:00  420.170013  421.299988  420.170013  421.255005
# 2024-05-15 11:30:00-04:00  421.279999  422.084991  420.709991  421.640015
# 2024-05-15 12:00:00-04:00  421.609985  421.679993  420.690002  421.429993
# 2024-05-15 12:30:00-04:00  421.420013  421.850006  421.100006  421.839996
# 2024-05-15 13:00:00-04:00  421.869995  422.609985  421.823608  422.570007
# 2024-05-15 13:30:00-04:00  422.550995  423.059998  422.239990  422.954987
# 2024-05-15 14:00:00-04:00  422.969910  423.670013  422.850006  423.540009
# 2024-05-15 14:30:00-04:00  423.579987  423.589996  423.059998  423.260010
# 2024-05-15 15:00:00-04:00  423.220001  423.299988  423.109985  423.160004
#
#                             Volume  Dividends  Stock Splits
# Datetime
# 2024-05-15 09:30:00-04:00  2649674        0.0           0.0
# 2024-05-15 10:00:00-04:00  1113141        0.0           0.0
# 2024-05-15 10:30:00-04:00  1014193        0.0           0.0
# 2024-05-15 11:00:00-04:00  1445172        0.0           0.0
# 2024-05-15 11:30:00-04:00  1099805        0.0           0.0
# 2024-05-15 12:00:00-04:00   788690        0.0           0.0
# 2024-05-15 12:30:00-04:00   477514        0.0           0.0
# 2024-05-15 13:00:00-04:00   631615        0.0           0.0
# 2024-05-15 13:30:00-04:00   574880        0.0           0.0
# 2024-05-15 14:00:00-04:00   627060        0.0           0.0
# 2024-05-15 14:30:00-04:00  1350213        0.0           0.0
# 2024-05-15 15:00:00-04:00    54954        0.0           0.0
# /Users/cbuff/Library/Caches/pypoetry/virtualenvs/lenny-api-lH9a1Hpg-py3.12/lib/python3.12/site-packages/yfinance/scrapers/history.py:231: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   quotes2 = quotes.resample('30T')
# /var/folders/qj/x48mh3kn2mqd8h_yvbjh67w40000gn/T/ipykernel_81840/876898259.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   last_close_price = yticker.history(interval='1d', period='2d')['Close'][0]
# /var/folders/qj/x48mh3kn2mqd8h_yvbjh67w40000gn/T/ipykernel_81840/876898259.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = yticker.history(interval='15m', period='1d')['Close'][-1]

# %%
yticker = yf.Ticker('MSFT')
df = yticker.history(interval='1d', period='5y')[["Close"]].head(2)

res = []
for idx, row in df.iterrows():
    res.append({'timestamp': str(idx), 'price': row['Close']})

res
# Out:
# [{'timestamp': '2024-01-02 00:00:00-05:00', 'price': 369.5189208984375},
#  {'timestamp': '2024-01-03 00:00:00-05:00', 'price': 369.2499084472656}]
